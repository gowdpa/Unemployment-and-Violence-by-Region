# %% [markdown]
# <a href="https://colab.research.google.com/github/gowdpa/Unemployment-and-Violence-by-Region/blob/main/Gowdy_Feeder_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview
# During this process, you will use Python to create a data subset of a larger data set
#
# This is designed for someone with little to no experience with Python.
#
# The overall process will proceed as follows:
#
# 1. Import necessary packages
# 2. Read in a .csv file to create a dataframe
# 3. Filter to create a subset of that dataframe that only contains relevant information
# 3. Export new subset as another .csv

# %% [markdown]
# #### Filtering a Data Set
#
# This code will filter a data set named `"CountyHealthData_2014-2015.csv"`
#
# This code will filter down the large data from the County Health Data set into a smaller data set that will let us analyze the correlation between Unemployment and Violent Crime by Region.
#
# Begin by importing the pandas package using the following command:

# %% [markdown]
# You should download the csv file `"CountyHealthData_2014-2015.csv"` to follow along, or you can repeat these steps with your own data, saved as a csv file.
# To import a .csv file to make it workable, follow these steps:
# 1. Click on the 5th icon down in CoLab, it should look like a folder.
# 2. There will be a row of icons under the word "Files." Click the icon that looks like a paper with a folded down corner and contains the up arrow.
# 3. Your computer files should pop up. Find where your data set is stored on your computer. Click on the data set, then click "open." This will being the data set into CoLAb to make it workable. It will take a second for the data set to upload, be patient.
#
# NOTE: make sure that your csv file is saved in the same working directory as your .ipynb notebook file that you will use.
#
#
# To read the dataframe object, we'll define our object df by executing the `pd.read_csv()` function on our data file by inserting the relative data file's name into the parathenses. To define the data frame, you will type the name that you will use in your code, and set it equal to the `pd.read_csv()` function.
#
#
# To now use your data set to run the any functions, use the following command:

# %%
import pandas as pd

# %%
df=pd.read_csv("CountyHealthData_2014-2015.csv")

# %% [markdown]
# To start, we will explore the dataframe by looking at some basic attributes. These attributes contain values that provide helpful information about the dataframe, that guide our interaction with the dataframe.
#
# Using pandas, we access attributes with the following syntax:
#
# `<DataFrame name>.<attribute name>`
#
# The `.shape` attribute is used to determine how many rows and columns (in that order) are available.
#
# The `.size` attribute is used to show the number of cells in the dataframe (rows * columns).
#
# The `.columns` attribute provides the column names for the dataframe

# %%
df.shape
# Out:
# (6109, 64)

# %%
df.size
# Out:
# 390976

# %%
df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
# ...

# %% [markdown]
# ` .value_counts()` is one of the most useful methods for categorical variables, as it  provides a frequency table.

# %%
df.Region.value_counts()
# Out:
# South        2803
# Midwest      2038
# West          834
# Northeast     434
# Name: Region, dtype: int64

# %% [markdown]
# Often you will want to select certain rows, columns, or specific cells from a large dataframe. This can be accomplished using indexing. There are some limitations, however.
#
# For example, we can use numbers in square brackets to select certain rows, but doing so always returns all the columns in our dataset, such as the function: `df [0:3]`
#
# If we use the `.iloc` attribute before our brackets, pandas accepts two numbers separated by a comma. The first number is for rows and the second for columns. This will give us the information of a specefic cell, as shown in the following function:

# %%
df.iloc[2,3]
# Out:
# 'Anchorage Borough'

# %% [markdown]
# We can also select information for specific columns using the column names, however, you MUST type out the column name, and you cannot use the column number.
#
# The dataset can also be filtered by using logical conditions (based on true or false), these can be added using nested square brackets.
#
# See the example below.
#
# - The inner statement, `df["State"]=="RI"` looks for a column name and checks if it equals `"RI"`
# - The outer statement `df[ ... ]` uses the resulting column of `True/False` values to select rows
# - When combined, these two commands call all of the data contained in rows where the value of the `State` field is equal to `"RI"`

# %%
df[df["State"] == "RI"]
# Out:
#      State     Region     Division             County   FIPS  GEOID  \
# 4505    RI  Northeast  New England     Bristol County  44001  44001
# 4506    RI  Northeast  New England     Bristol County  44001  44001
# 4507    RI  Northeast  New England        Kent County  44003  44003
# 4508    RI  Northeast  New England        Kent County  44003  44003
# 4509    RI  Northeast  New England     Newport County  44005  44005
# 4510    RI  Northeast  New England     Newport County  44005  44005
# 4511    RI  Northeast  New England  Providence County  44007  44007
# 4512    RI  Northeast  New England  Providence County  44007  44007
# 4513    RI  Northeast  New England  Washington County  44009  44009
# 4514    RI  Northeast  New England  Washington County  44009  44009
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 4505  Region 12  1/1/2014           4543.0                0.087  ...
# 4506  Region 12  1/1/2015           3891.0                0.087  ...
# ...

# %% [markdown]
# To select multiple columns, it must be listed in its own nested set of square brackets.
#
# See the examples below

# %%
df[["State","Region","Division","County","Unemployment"]]
# Out:
#      State Region  Division                      County  Unemployment
# 0       AK   West   Pacific  Aleutians West Census Area         0.091
# 1       AK   West   Pacific  Aleutians West Census Area         0.088
# 2       AK   West   Pacific           Anchorage Borough         0.054
# 3       AK   West   Pacific           Anchorage Borough         0.050
# 4       AK   West   Pacific          Bethel Census Area         0.152
# ...    ...    ...       ...                         ...           ...
# 6104    WY   West  Mountain                Uinta County         0.047
# 6105    WY   West  Mountain             Washakie County         0.054
# 6106    WY   West  Mountain             Washakie County         0.050
# 6107    WY   West  Mountain               Weston County         0.051
# 6108    WY   West  Mountain               Weston County         0.043
#
# [6109 rows x 5 columns]

# %%
df[["State","Region","Division","County","Unemployment","Violent crime"]]
# Out:
#      State Region  Division                      County  Unemployment  \
# 0       AK   West   Pacific  Aleutians West Census Area         0.091
# 1       AK   West   Pacific  Aleutians West Census Area         0.088
# 2       AK   West   Pacific           Anchorage Borough         0.054
# 3       AK   West   Pacific           Anchorage Borough         0.050
# 4       AK   West   Pacific          Bethel Census Area         0.152
# ...    ...    ...       ...                         ...           ...
# 6104    WY   West  Mountain                Uinta County         0.047
# 6105    WY   West  Mountain             Washakie County         0.054
# 6106    WY   West  Mountain             Washakie County         0.050
# 6107    WY   West  Mountain               Weston County         0.051
# 6108    WY   West  Mountain               Weston County         0.043
#
#       Violent crime
# 0            322.06
# 1            317.35
# 2            840.06
# 3            823.16
# ...

# %% [markdown]
# `.iloc` is used for intergers, whereas `.loc` is used for column names.
#
# To index with loc, the function `df.loc[:,[...]]` is used. If specific rows were selected, those numbers would go where the semi colon is: `df.loc[0:3,[...]]`. The values inside of the second brackets are the column names. To recieve a random sample, `.sample(n=)` is added at the end of the function.
#
# All together, the function should appear like this: `df.[:,[...]].sample(n=)`

# %%
df.loc[:,["State","Region","Division","County","Unemployment","Violent crime"]].sample(n=50)
# Out:
#      State     Region            Division             County  Unemployment  \
# 1809    KS    Midwest  West North Central      Graham County         0.031
# 5649    VA      South      South Atlantic     Roanoke County         0.052
# 111     AL      South  East South Central        Hale County         0.099
# 2729    MN    Midwest  West North Central     Stearns County         0.055
# 4493    PA  Northeast        Mid-Atlantic      Warren County         0.067
# 4087    OH    Midwest  East North Central  Montgomery County         0.080
# 2561    MI    Midwest  East North Central   Roscommon County         0.115
# 1898    KS    Midwest  West North Central        Rice County         0.039
# 877     GA      South      South Atlantic      Gordon County         0.091
# 6016    WV      South      South Atlantic      Monroe County         0.057
# 724     FL      South      South Atlantic  Santa Rosa County         0.077
# ...

# %%
df.loc[:,["State","Region","Division","Unemployment","Violent crime"]].sample(n=50)
# Out:
#      State     Region            Division  Unemployment  Violent crime
# 3048    MS      South  East South Central         0.097            NaN
# 4893    TN      South  East South Central         0.087         510.72
# 4633    SD    Midwest  West North Central         0.073           9.79
# 3645    NE    Midwest  West North Central         0.042          34.60
# 1255    IA    Midwest  West North Central         0.062         264.50
# 1406    IL    Midwest  East North Central         0.070         134.14
# 4526    SC      South      South Atlantic         0.126         813.80
# 2042    KY      South  East South Central         0.074         160.64
# 3786    NM       West            Mountain         0.087         626.75
# 1199    IA    Midwest  West North Central         0.048         240.65
# 4097    OH    Midwest  East North Central         0.100          46.64
# 3952    NY  Northeast        Mid-Atlantic         0.076         161.59
# ...

# %%
df.loc[:,["State","Region","Unemployment","Violent crime"]].sample(n=300)
# Out:
#      State   Region  Unemployment  Violent crime
# 335     AZ     West         0.081         376.42
# 1971    KY    South         0.083          55.49
# 3993    OH  Midwest         0.076         119.11
# 5909    WI  Midwest         0.069         108.26
# 4050    OH  Midwest         0.102          41.17
# ...    ...      ...           ...            ...
# 5151    TX    South         0.063         315.61
# 1188    IA  Midwest         0.053         226.15
# 5693    VA    South         0.134         205.44
# 2223    LA    South         0.072         345.64
# 2760    MO  Midwest         0.054         397.88
#
# [300 rows x 4 columns]

# %% [markdown]
# ####Creating a New Dataframe
# Now a new dataframe needs to be created for this data set. This will be useful to export this data.
#
# To do this, name the data using the same process as initally, but instead  of using `pd.read_csv()`we will use the function that created our data set.
#
# Set the name of your new dataframe (here I am using `UseableData`) equal to the function that created your data set.

# %%
UseableData=df.loc[:,["State","Region","Unemployment","Violent crime"]].sample(n=300).copy()

# %% [markdown]
# We can run `UseableData` to test that we did the previous step correctly.

# %%
UseableData
# Out:
#      State   Region  Unemployment  Violent crime
# 5410    UT     West         0.039          41.47
# 384     CA     West         0.094         399.61
# 591     CO     West         0.040          66.82
# 3090    MS    South         0.155            NaN
# 1166    IA  Midwest         0.044          13.75
# ...    ...      ...           ...            ...
# 3041    MS    South         0.142            NaN
# 4543    SC    South         0.115         753.71
# 1677    IN  Midwest         0.079            NaN
# 653     FL    South         0.076         688.94
# 2779    MO  Midwest         0.056         406.31
#
# [300 rows x 4 columns]

# %% [markdown]
# #### Exporting to .csv file
#
# In order to export the data to a csv, we can use the method `.to_csv()` - adding the filename and extension within the parentheses at the end.
#
# For our filtered subset we would run: `UseableData_subset.to_csv("UseableData_subset.csv")` this will export a `.csv` file in our working directory.
#
# By default, this `.csv` will include the row of indices that pandas created when we read the original file into our notebook using `.read_csv`.
#
# To eliminate these, we can add `index=false` to our statement, which tells it not bring in those index numbers.
#
# `UseableData_subset.to_csv("UseableData_subset.csv", index=False)`

# %%
UseableData.to_csv("UseableData_subset.csv", index=False)
